# %%
import os
os.environ['CUDA_PATH']
os.add_dll_directory(os.path.join(os.environ['CUDA_PATH'], 'bin'))
os.add_dll_directory("C:/Users/picokatx/Documents/cudaquest/.venv/Lib/site-packages/torch/lib")
os.add_dll_directory("C:/Users/picokatx/Documents/cudaquest/.venv/Lib/site-packages/")
# Out:
# <AddedDllDirectory('C:/Users/picokatx/Documents/cudaquest/.venv/Lib/site-packages/')>

# %%
import lltm_cpp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import lltm_cpp
#
# ImportError: DLL load failed while importing lltm_cpp: The specified module could not be found.

# %%
from PIL import Image
img = Image.open("./delete.jpeg")

# %%
import base64
from io import BytesIO

buffered = BytesIO()
img.save(buffered, format="JPEG")
img_str = base64.b64encode(buffered.getvalue()).decode("utf-8")

# %%
'data:image/jpeg;base64,' +img_str
# Out:
# 'data:image/jpeg;base64,...'
